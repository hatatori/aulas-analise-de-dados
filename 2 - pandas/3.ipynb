# %%
import pandas as pd

# %%
market = pd.read_json('market.json')

# %%
market
# Out:
#         id                                               name  price  \
# 0   432306  Farofa de Mandioca Tradicional Típica D' Goiás...  14.79
# 1   433244                         Feijoada Qualitá Lata 420g  11.29
# 2   454418                         Frango Inteiro SWIFT 2,5kg  26.15
# 3   445688                          Tomate Pera Orgânico 300g   8.40
# 4   129204                   Azeitona Verde LA VIOLETERA 500g  23.49
# ..     ...                                                ...    ...
# 87  306310           Evian Águas Especiais Mineral Sem Gás 1L  17.99
# 88  306312        Evian Águas Especiais Mineral Sem Gás 750ML  19.79
# 89  176107         Chá Morango Chá Leão Caixa 20g 10 Unidades   8.29
# 90  685252           Água Mineral Natural Voss Com Gás 800ml.  41.79
# 91  437792  Bebida Funcional One More Sabor Cranberry e Gu...   7.19
#
#               img         brand   category
# 0      616655.png       D Goias  alimentos
# 1      583226.png       Qualitá  alimentos
# ...

# %%
market.head(5)
# Out:
#        id                                               name  price  \
# 0  432306  Farofa de Mandioca Tradicional Típica D' Goiás...  14.79
# 1  433244                         Feijoada Qualitá Lata 420g  11.29
# 2  454418                         Frango Inteiro SWIFT 2,5kg  26.15
# 3  445688                          Tomate Pera Orgânico 300g   8.40
# 4  129204                   Azeitona Verde LA VIOLETERA 500g  23.49
#
#             img         brand   category
# 0    616655.png       D Goias  alimentos
# 1    583226.png       Qualitá  alimentos
# 2  19417938.jpg         Swift  alimentos
# 3  23981441.jpg     Bandeiras  alimentos
# 4    547782.jpg  La Violetera  alimentos

# %%
market.tail(5)
# Out:
#         id                                               name  price  \
# 87  306310           Evian Águas Especiais Mineral Sem Gás 1L  17.99
# 88  306312        Evian Águas Especiais Mineral Sem Gás 750ML  19.79
# 89  176107         Chá Morango Chá Leão Caixa 20g 10 Unidades   8.29
# 90  685252           Água Mineral Natural Voss Com Gás 800ml.  41.79
# 91  437792  Bebida Funcional One More Sabor Cranberry e Gu...   7.19
#
#               img     brand category
# 87  13135425.jpeg     Evian  bebidas
# 88    9499384.png     Evian  bebidas
# 89   15064309.jpg      Leão  bebidas
# 90  22074380.jpeg      Voss  bebidas
# 91     664339.jpg  One More  bebidas

# %%
market[0:5]
# Out:
#        id                                               name  price  \
# 0  432306  Farofa de Mandioca Tradicional Típica D' Goiás...  14.79
# 1  433244                         Feijoada Qualitá Lata 420g  11.29
# 2  454418                         Frango Inteiro SWIFT 2,5kg  26.15
# 3  445688                          Tomate Pera Orgânico 300g   8.40
# 4  129204                   Azeitona Verde LA VIOLETERA 500g  23.49
#
#             img         brand   category
# 0    616655.png       D Goias  alimentos
# 1    583226.png       Qualitá  alimentos
# 2  19417938.jpg         Swift  alimentos
# 3  23981441.jpg     Bandeiras  alimentos
# 4    547782.jpg  La Violetera  alimentos

# %%
checks = market[0:5]['price']
checks
# Out:
# 0    14.79
# 1    11.29
# 2    26.15
# 3     8.40
# 4    23.49
# Name: price, dtype: float64

# %%
checks = market['price'] > 50
market[checks][0:5]
# Out:
#         id                                           name   price  \
# 21  458370                            PHOTODERM NUD MUITO   99.00
# 22  458363              Bioderma Sébium Pore Refiner 30ml  102.00
# 24  684725  NIVEA Serum Facial Cellular Luminous 630 30ml  135.99
# 25  457846       Neostrata MINESOL Oil Control FPS 70 40g   89.99
# 50  457855                           MINESOL OIL CONTR SE   79.90
#
#               img  brand             category
# 21     650568.jpg    NaN  beleza-e-perfumaria
# 22  12950454.jpeg    NaN  beleza-e-perfumaria
# 24  19759627.jpeg  Nivea  beleza-e-perfumaria
# 25   21508820.jpg    Roc  beleza-e-perfumaria
# 50   18763815.jpg    Roc  beleza-e-perfumaria

# %%
market[market['category'] == 'bebidas']
# Out:
#          id                                               name  price  \
# 61   705536               Chá Verde Orgânico Organic 10 Sachês  10.79
# 62   139689  Chá Herbal de Erva Doce TAEQ 22,5g com 15 Saqu...   6.49
# 63   556894      Xarope Fabbri Sabor Amarena Zero Açúcar 560ml  64.99
# 64  1387095                          Chá OETKER Vibre Mais 12g   9.89
# 65  1387096                            Chá OETKER Ame Mais 12g  10.79
# 66  1105029         Kombucha Manga Orgânica Tao Kombucha 275ml  14.49
# 67   346266      Bebida Uva com Cranberry Life Mix Caixa 200ml   2.25
# 68   331030                     Limonada Orgânica NATIVE 200ml   4.69
# 69   331032          Nectar de Tangerina Orgânico NATIVE 200ML   4.89
# 70   454143             Água Tônica PRATA CLUB SODA Lata 269ml   4.09
# 71   427796            Refrigerante Citrus Prata Garrafa 200ml   6.69
# 72   331031             Néctar Orgânico de Caju NATIVE 1 Litro  19.69
# ...

# %%
preco_max = market['price'].max()
preco_min = market['price'].min()

print( preco_max )
print( preco_min )
# Out:
# 209.9
# 1.19

# %%
market[market['category'] == 'bebidas'].size # quantity lines
# Out:
# 186

# %%
market.columns
# Out:
# Index(['id', 'name', 'price', 'img', 'brand', 'category'], dtype='object')

# %%
media = market['price'].mean()
soma = market['price'].sum()

print( media )
print( soma )
# Out:
# 32.095978260869565
# 2952.83

# %%
market.sort_values('name')
# Out:
#         id                                               name  price  \
# 68  331030                     Limonada Orgânica NATIVE 200ml   4.69
# 77  143060                       Alecrim CHINATOWN Pacote 20g   4.89
# 60  381376  Aparelho de Barbear BIC Soleil Sensitive com 2...  12.79
# 37  427861  Aparelho de Barbear Descartável Gillette Prest...  17.23
# 7    41329            Arroz Agulhinha Tipo 1 CAMIL Pacote 5kg  22.79
# ..     ...                                                ...    ...
# 70  454143             Água Tônica PRATA CLUB SODA Lata 269ml   4.09
# 73  454145                       Água Tônica PRATA Lata 269ml   3.99
# 74  427794                    Água Tônica Prata Garrafa 200ml   5.79
# 83   79335                            Água de Coco TAEQ 200ml   2.99
# 14  131661                        Óleo de Soja LIZA Pet 900ml   9.39
#
#               img      brand             category
# 68     601330.jpg     Native              bebidas
# ...
